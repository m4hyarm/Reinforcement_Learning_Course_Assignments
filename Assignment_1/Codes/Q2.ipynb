# %%
from BP_reward import get_reward
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from statistics import NormalDist
import scipy.stats
from doctors import *

# %% [markdown]
# # Inputs

# %%
s_id = 810100476
drugs = [1, 2]

# %% [markdown]
# # Plots

# %%
rewards_mean_A, _ = doctor_A(s_id, drugs)
rewards_mean_B, _ = doctor_B(s_id, drugs)
rewards_mean_C, _ = doctor_C(s_id, drugs)

plt.subplots(3,1, figsize=(20,18), sharex=True, sharey=True)
plt.subplot(311)
plt.plot(range(1,101), rewards_mean_A, label='win-stay lose-shift')
plt.ylabel('Reward', fontsize=15, labelpad=10)
plt.legend(fontsize=30)
plt.grid()

plt.subplot(312)
plt.plot(range(1,101), rewards_mean_B, label='fully random')
plt.ylabel('Reward', fontsize=15, labelpad=10)
plt.legend(fontsize=30)
plt.grid()

plt.subplot(313)
plt.plot(range(1,101), rewards_mean_C, label='doctor C')
plt.xlabel('Trial', fontsize=15, labelpad=10)
plt.ylabel('Reward', fontsize=15, labelpad=10)
plt.legend(fontsize=30)
plt.grid()

plt.xticks(ticks=[1,20,40,60,80,100], labels=[1,20,40,60,80,100])
plt.suptitle('Reward per Trial', y=0.99, fontsize=35)
plt.tight_layout(pad=1)

# %% [markdown]
# ---
