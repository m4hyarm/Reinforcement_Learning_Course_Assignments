# %%
from env import *
import numpy as np

# %% [markdown]
# # Q1

# %%
ACTION_SPACE    = [0, 1, 2, 3]  # 0:LEFT , 1:DOWN , 2:RIGHT , 3:UP
studentNum      = 810100476
shape           = [6,6]
safe_break_prob = 0.0001
notSlipProb     = 0.94
moveReward      = -1
failReward      = -10
goalReward      = +100
discount_factor = 0.9
theta           = 0.01
random_break    = False

# %%
MAP, safe_path = make_map(shape, studentNum, safe_break_prob, random_break)
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)

# %%
Environment.render(safe_path, map=True)

# %% [markdown]
# ### Policy Iteration

# %%
Environment.Policy_Iteration()
# Out:
# Iteration: 1
# Number of Evaluation Iterations: 14
# ------------------------------------
# Iteration: 2
# Number of Evaluation Iterations: 39
# ------------------------------------
# Iteration: 3
# Number of Evaluation Iterations: 29
# ------------------------------------
# Iteration: 4
# Number of Evaluation Iterations: 29
# ------------------------------------
# Iteration: 5
# Number of Evaluation Iterations: 4
# ------------------------------------
#
# Time Elapsed: 0.339s

# %%
Environment.Qvalues()
# Out:
#          Left       Down      Right         Up
# 0   17.233433  20.013659  -9.167616  17.233433
# 1    0.000000   0.000000   0.000000   0.000000
# 2    0.000000   0.000000   0.000000   0.000000
# 3    0.000000   0.000000   0.000000   0.000000
# 4    0.000000   0.000000   0.000000   0.000000
# 5    0.000000   0.000000   0.000000   0.000000
# 6   21.376364  24.522830  -9.048534  16.722636
# 7    0.000000   0.000000   0.000000   0.000000
# 8    0.000000   0.000000   0.000000   0.000000
# 9    0.000000   0.000000   0.000000   0.000000
# 10   0.000000   0.000000   0.000000   0.000000
# 11   0.000000   0.000000   0.000000   0.000000
# 12  25.716737  29.438069  -8.777984  20.723963
# 13   0.000000   0.000000   0.000000   0.000000
# 14   0.000000   0.000000   0.000000   0.000000
# 15   0.000000   0.000000   0.000000   0.000000
# 16   0.000000   0.000000   0.000000   0.000000
# 17   0.000000   0.000000   0.000000   0.000000
# 18  30.666671  35.048159  -8.473204  25.098160
# ...

# %%
Environment.render(safe_path)

# %% [markdown]
# ### Value Iteration

# %%
Environment.Value_Iteration()
# Out:
# Number of Iterations: 15
# Time Elapsed: 0.045s

# %%
Environment.Qvalues()
# Out:
#          Left       Down      Right         Up
# 0   17.233465  20.013658  -9.167615  17.233465
# 1    0.000000   0.000000   0.000000   0.000000
# 2    0.000000   0.000000   0.000000   0.000000
# 3    0.000000   0.000000   0.000000   0.000000
# 4    0.000000   0.000000   0.000000   0.000000
# 5    0.000000   0.000000   0.000000   0.000000
# 6   21.376363  24.522830  -9.048533  16.722668
# 7    0.000000   0.000000   0.000000   0.000000
# 8    0.000000   0.000000   0.000000   0.000000
# 9    0.000000   0.000000   0.000000   0.000000
# 10   0.000000   0.000000   0.000000   0.000000
# 11   0.000000   0.000000   0.000000   0.000000
# 12  25.716737  29.438069  -8.777984  20.723962
# 13   0.000000   0.000000   0.000000   0.000000
# 14   0.000000   0.000000   0.000000   0.000000
# 15   0.000000   0.000000   0.000000   0.000000
# 16   0.000000   0.000000   0.000000   0.000000
# 17   0.000000   0.000000   0.000000   0.000000
# 18  30.666671  35.048159  -8.473204  25.098159
# ...

# %%
Environment.render(safe_path)

# %% [markdown]
# ---
# ---
# # Q2

# %%
ACTION_SPACE    = [0, 1, 2, 3]  # 0:LEFT , 1:DOWN , 2:RIGHT , 3:UP
studentNum      = 810100476
shape           = [6,6]
safe_break_prob = 0.001
notSlipProb     = 0.7
moveReward      = -1
failReward      = -10
goalReward      = +100
discount_factor = 0.9
theta           = 0.01
random_break    = True

# %%
MAP, safe_path = make_map(shape, studentNum, safe_break_prob, random_break)
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)

# %%
Environment.render(safe_path, map=True)

# %% [markdown]
# ### Policy Iteration

# %%
Environment.Policy_Iteration()
# Out:
# Iteration: 1
# Number of Evaluation Iterations: 18
# ------------------------------------
# Iteration: 2
# Number of Evaluation Iterations: 28
# ------------------------------------
# Iteration: 3
# Number of Evaluation Iterations: 22
# ------------------------------------
# Iteration: 4
# Number of Evaluation Iterations: 11
# ------------------------------------
# Iteration: 5
# Number of Evaluation Iterations: 7
# ------------------------------------
#
# Time Elapsed: 0.284s

# %%
Environment.Qvalues()
# Out:
#          Left       Down      Right         Up
# 0   -0.457867  -0.064810  -2.315360  -0.457867
# 1   -2.244376  -5.726671  -5.300571  -2.821296
# 2   -4.664813  -7.277585  -8.968898  -5.122424
# 3   -6.480573  -8.521305  -6.821992  -6.069067
# 4   -9.137203  -5.745040  -6.960520  -5.874012
# 5   -6.742627  -7.532218  -6.031737  -6.031737
# 6    0.729479   1.853180  -4.388606  -0.906311
# 7   -0.929113  -2.917772  -5.997031  -3.384258
# 8   -6.228508  -1.237228  -7.843140  -5.802408
# 9   -6.657406   0.130753  -4.956555  -8.348719
# 10  -8.231579  -2.838190  -7.393637  -6.532265
# 11  -5.680882  -8.722755  -5.775197  -6.896362
# 12   3.675033   5.061372  -0.653060   1.335599
# 13   1.763682  -1.405986   0.513177  -4.478103
# 14  -1.773596   2.904731   1.935304  -4.852855
# 15   2.156929  14.177938   0.944406  -4.448982
# 16   2.503084   9.598616  -5.626098  -2.584225
# 17  -2.377381  -7.754831  -3.322544  -6.932828
# 18   6.811493   8.759646   1.036022   4.205691
# ...

# %%
Environment.render(safe_path)

# %% [markdown]
# ### Value Iteration

# %%
Environment.Value_Iteration()
# Out:
# Number of Iterations: 21
# Time Elapsed: 0.062s

# %%
Environment.Qvalues()
# Out:
#          Left       Down      Right         Up
# 0   -0.462414  -0.067440  -2.319635  -0.462414
# 1   -2.248845  -5.728474  -5.303798  -2.825622
# 2   -4.668468  -7.278539  -8.969865  -5.125496
# 3   -6.482916  -8.521806  -6.822440  -6.070755
# 4   -9.137250  -5.744978  -6.960089  -5.873899
# 5   -6.742456  -7.532069  -6.031221  -6.031221
# 6    0.727682   1.852074  -4.389827  -0.910199
# 7   -0.930782  -2.918617  -5.997793  -3.387722
# 8   -6.229311  -1.237640  -7.843526  -5.804635
# 9   -6.657526   0.130719  -4.956580  -8.348852
# 10  -8.231569  -2.838178  -7.393599  -6.532203
# 11  -5.680805  -8.722684  -5.775082  -6.895916
# 12   3.674469   5.061033  -0.653490   1.334345
# 13   1.763250  -1.406128   0.513021  -4.478650
# 14  -1.773812   2.904683   1.935257  -4.852988
# 15   2.156895  14.177932   0.944401  -4.448991
# 16   2.503081   9.598616  -5.626097  -2.584218
# 17  -2.377377  -7.754826  -3.322537  -6.932798
# 18   6.811342   8.759553   1.035938   4.205316
# ...

# %%
Environment.render(safe_path)

# %% [markdown]
# ---
# ---
# # Q3

# %%
ACTION_SPACE    = [0, 1, 2, 3]  # 0:LEFT , 1:DOWN , 2:RIGHT , 3:UP
studentNum      = 810100476
shape           = [15,15]
safe_break_prob = 0.001
notSlipProb     = 0.7
moveReward      = -1
failReward      = -10
goalReward      = +100
discount_factor = 0.9
theta           = 0.01
random_break    = True

# %%
MAP, safe_path = make_map(shape, studentNum, safe_break_prob, random_break)
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)

# %%
Environment.render(safe_path, map=True)

# %% [markdown]
# ### Value Iteration ( theta = 1 )

# %%
theta = 1
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)
Environment.Value_Iteration()
# Out:
# Number of Iterations: 13
# Time Elapsed: 0.293s

# %%
Environment.render(safe_path)

# %% [markdown]
# ### Value Iteration ( theta = 0.01 )

# %%
theta = 0.01
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)
Environment.Value_Iteration()
# Out:
# Number of Iterations: 26
# Time Elapsed: 0.509s

# %%
Environment.render(safe_path)

# %% [markdown]
# ### Value Iteration ( theta = 0.000001 )

# %%
theta = 0.000001
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)
Environment.Value_Iteration()
# Out:
# Number of Iterations: 60
# Time Elapsed: 1.099s

# %%
Environment.render(safe_path)

# %% [markdown]
# ### Value Iteration ( theta = 0.01 ) ( Goal reward = 20000 )

# %%
theta      = 0.01
goalReward = 20000
Environment = FrozenLake(ACTION_SPACE, MAP, notSlipProb, goalReward, moveReward, failReward, discount_factor, theta)
Environment.Value_Iteration()
# Out:
# Number of Iterations: 43
# Time Elapsed: 0.935s

# %%
Environment.render(safe_path)

# %% [markdown]
# ---

# %% [markdown]
# ---
